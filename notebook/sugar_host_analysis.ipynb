# %%
import sugar_analysis as sa
import numpy as np
import cPickle as pkl
import matplotlib.pyplot as plt

# %%
global_mass='../../lsfr_analysis/lssfr_paper_full_sntable.csv'
host_prop =  np.loadtxt(global_mass,skiprows=1,delimiter=',', dtype='str')
sample_mick = list(host_prop[:,16])
print sample_mick
# Out:
# ['CSS110918_02', 'CSS120424_01', 'CSS130502_01', 'LSQ12ekl', 'LSQ12fmx', 'LSQ13vy', 'PTF09dlc', 'PTF09dnl', 'PTF09dnp', 'PTF09foz', 'PTF10hmv', 'PTF10mwb', 'PTF10qjl', 'PTF10qjq', 'PTF10tce', 'PTF10wnm', 'PTF10wof', 'PTF10xyt', 'PTF10zdk', 'PTF11bnx', 'PTF11cao', 'PTF11mty', 'PTF11pbp', 'PTF12dxm', 'PTF12iiq', 'SN2004ef', 'SN2004gc', 'SN2005hc', 'SN2005hj', 'SN2005ir', 'SN2006cj', 'SN2006dm', 'SN2006do', 'SN2006ob', 'SN2007bc', 'SN2007bd', 'SN2007cq', 'SN2007kk', 'SN2007nq', 'SN2009hi', 'SN2010dt', 'SN2010ex', 'SNF20050624-000', 'SNF20050728-000', 'SNF20050728-006', 'SNF20050821-007', 'SNF20050829-003', 'SNF20050927-005', 'SNF20051003-004', 'SNF20060511-014', 'SNF20060512-001', 'SNF20060512-002', 'SNF20060521-001', 'SNF20060521-008', 'SNF20060526-003', 'SNF20060530-003', 'SNF20060609-002', 'SNF20060618-014', 'SNF20060621-012', 'SNF20060621-015', 'SNF20060624-019', 'SNF20060907-000', 'SNF20060912-000', 'SNF20060912-004', 'SNF20060916-002', 'SNF20061011-005', 'SNF20061020-000', 'SNF200
# ...

# %%
rids_sugar_q1 = sa.read_input_data_SNf(res_dict_path='../../sugar_analysis_data/resfitlc_SNf_5new_fU_10new_fI_10_sugarq1.pkl', model_name='sugar')
rids_sugar_q1.build_HD_data()
for sn_name in sample_mick:
    if sn_name not in rids_sugar_q1.sn_name:
        print sn_name
sample_mick.remove('SNF20050728-000')      
sample_mick.remove('SNF20060907-000')
# Out:
# SNF20050728-000
# SNF20060907-000

# %%
rids_sugar_q1 = sa.read_input_data_SNf(res_dict_path='../../sugar_analysis_data/resfitlc_SNf_5new_fU_10new_fI_10_sugarq1.pkl', model_name='sugar')
rids_sugar_q1.build_HD_data()
for sn_name in sample_mick:
    if sn_name not in rids_sugar_q1.sn_name:#
        print sn_name
sample_fixed = sample_mick

# %%
model_name='sugar'
rids_sugar = sa.read_input_data_SNf(res_dict_path='../../sugar_analysis_data/resfitlc_SNf_5new_fU_10new_fI_10_sugar.pkl',model_name=model_name, select=sample_fixed)
rids_sugar.build_HD_data()
HD_sugar = sa.get_hubblefit(rids_sugar.params, rids_sugar.cov, rids_sugar.zhl, rids_sugar.zcmb, rids_sugar.zerr)
HD_sugar.fit()
# Out:
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: errordef is not given. Default to 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter Mb is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter alpha1 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter alpha2 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# ...

# %%
model_name='salt2'
rids_salt2 = sa.read_input_data_SNf(res_dict_path='../../sugar_analysis_data/resfitlc_SNf_5new_fU_10new_fI_10_salt2.pkl',model_name=model_name, select=sample_fixed)
rids_salt2.build_HD_data()
HD_salt2 = sa.get_hubblefit(rids_salt2.params, rids_salt2.cov, rids_salt2.zhl, rids_salt2.zcmb, rids_salt2.zerr)
HD_salt2.fit()
# Out:
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: errordef is not given. Default to 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter Mb is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter alpha1 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter alpha2 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# <hr>
#         <table>
#             <tr>
# ...

# %%
model_name='salt2'
rids_salt2 = sa.read_input_data_SNf(res_dict_path='../../sugar_analysis_data/resfitlc_SNf_3fB_10fR_10_salt2.pkl',model_name=model_name, select=sample_fixed)
rids_salt2.build_HD_data()
HD_salt2 = sa.get_hubblefit(rids_salt2.params, rids_salt2.cov, rids_salt2.zhl, rids_salt2.zcmb, rids_salt2.zerr)
HD_salt2.fit()
# Out:
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: errordef is not given. Default to 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter Mb is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter alpha1 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter alpha2 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# <hr>
#         <table>
#             <tr>
# ...

# %% [markdown]
# # Correlation  Hubble residuals with hosts properties (UBVRI)

# %% [markdown]
# ## Sugar q1

# %%
model_name='sugar'
rids_sugar_q1 = sa.read_input_data_SNf(res_dict_path='../../sugar_analysis_data/resfitlc_SNf_5new_fU_10new_fI_10_sugarq1.pkl', model_name=model_name, select=sample_fixed)
rids_sugar_q1.build_HD_data()
rids_sugar_q1.build_host()
HD_sugar_q1 = sa.get_hubblefit(rids_sugar_q1.params, rids_sugar_q1.cov, rids_sugar_q1.zhl, rids_sugar_q1.zcmb, rids_sugar_q1.zerr, lssfr=np.column_stack((rids_sugar_q1.lssfr,rids_sugar_q1.P_delayed)),sn_name=rids_sugar_q1.sn_name)
HD_sugar_q1.comp_mass_step_modefit(model_name=model_name)
HD_sugar_q1.dump_pkl(outpath='../../lsfr_analysis/HD_results_sugarq1_UBVRI.pkl')
# Out:
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: errordef is not given. Default to 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter Mb is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter alpha1 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter alpha2 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# <hr>
#         <table>
#             <tr>
# ...

# %% [markdown]
# ## SUGAR

# %%
model_name='sugar'
rids_sugar = sa.read_input_data_SNf(res_dict_path='../../sugar_analysis_data/resfitlc_SNf_5new_fU_10new_fI_10_sugar.pkl',model_name=model_name, select=sample_fixed)
rids_sugar.build_HD_data()
rids_sugar.build_host()
HD_sugar = sa.get_hubblefit(rids_sugar.params, rids_sugar.cov, rids_sugar.zhl, rids_sugar.zcmb, rids_sugar.zerr, lssfr=np.column_stack((rids_sugar.lssfr,rids_sugar.P_delayed)),sn_name=rids_sugar.sn_name)
HD_sugar.comp_mass_step_modefit(model_name=model_name)
HD_sugar.dump_pkl(outpath='../../lsfr_analysis/HD_results_sugar_UBVRI.pkl')
# Out:
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: errordef is not given. Default to 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter Mb is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter alpha1 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter alpha2 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# ...

# %% [markdown]
# ## SALT2

# %%
model_name='salt2'
rids_salt2 = sa.read_input_data_SNf(res_dict_path='../../sugar_analysis_data/resfitlc_SNf_5new_fU_10new_fI_10_salt2.pkl',model_name=model_name, select=sample_fixed)
rids_salt2.build_HD_data()
rids_salt2.build_host()
HD_salt2 = sa.get_hubblefit(rids_salt2.params, rids_salt2.cov, rids_salt2.zhl, rids_salt2.zcmb, rids_salt2.zerr, lssfr=np.column_stack((rids_salt2.lssfr,rids_salt2.P_delayed)),sn_name=rids_salt2.sn_name)
HD_salt2.comp_mass_step_modefit(model_name=model_name)
HD_salt2.dump_pkl(outpath='../../lsfr_analysis/HD_results_salt2_UBVRI.pkl')
# Out:
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: errordef is not given. Default to 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter Mb is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter alpha1 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter alpha2 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# <hr>
#         <table>
#             <tr>
# ...

# %% [markdown]
# # Correlation  Hubble residuals with hosts properties (BVR)

# %% [markdown]
# ## SUGAR

# %%
model_name='sugar'
rids_sugar = sa.read_input_data_SNf(res_dict_path='../../sugar_analysis_data/resfitlc_SNf_3fB_10fR_10_sugar.pkl',model_name=model_name, select=sample_fixed)
rids_sugar.build_HD_data()
rids_sugar.build_host()
HD_sugar = sa.get_hubblefit(rids_sugar.params, rids_sugar.cov, rids_sugar.zhl, rids_sugar.zcmb, rids_sugar.zerr, lssfr=np.column_stack((rids_sugar.lssfr,rids_sugar.P_delayed)),sn_name=rids_sugar.sn_name)
HD_sugar.comp_mass_step_modefit(model_name=model_name)
HD_sugar.dump_pkl(outpath='../../lsfr_analysis/HD_results_sugar_BVR.pkl')
# Out:
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: errordef is not given. Default to 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter Mb is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter alpha1 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter alpha2 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# ...

# %% [markdown]
# ## SALT2

# %%
model_name='salt2'
rids_salt2 = sa.read_input_data_SNf(res_dict_path='../../sugar_analysis_data/resfitlc_SNf_3fB_10fR_10_salt2.pkl',model_name=model_name, select=sample_fixed)
rids_salt2.build_HD_data()
rids_salt2.build_host()
HD_salt2 = sa.get_hubblefit(rids_salt2.params, rids_salt2.cov, rids_salt2.zhl, rids_salt2.zcmb, rids_salt2.zerr, lssfr=np.column_stack((rids_salt2.lssfr,rids_salt2.P_delayed)),sn_name=rids_salt2.sn_name)
HD_salt2.comp_mass_step_modefit(model_name=model_name)
HD_salt2.dump_pkl(outpath='../../lsfr_analysis/HD_results_salt2_BVR.pkl')
# Out:
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: errordef is not given. Default to 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter Mb is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter alpha1 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter alpha2 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# <hr>
#         <table>
#             <tr>
# ...

# %%
HD_salt2.freeparameters
# Out:
# ['Mb', 'alpha1', 'alpha2']

# %% [markdown]
# # Correlation betwenn parameters

# %%
HD_res_sugar_UBVRI = pkl.load(open('../../lsfr_analysis/HD_results_sugar_UBVRI.pkl'))
HD_res_salt2_UBVRI = pkl.load(open('../../lsfr_analysis/HD_results_salt2_UBVRI.pkl'))
fig = plt.figure(figsize=[8,6])
ax = fig.add_subplot(111)
mb_salt, mb_sugar = [],[]

for name, HD_salt2 in HD_res_salt2_UBVRI['data'].items():
    if name not in HD_res_sugar_UBVRI['data'].keys():
        print("%s not in sugar"%name)
    else:
        ax.scatter(HD_res_salt2_UBVRI['data'][name]['mb'], HD_res_sugar_UBVRI['data'][name]['mb'], color='r')
    
ax.set_ylabel("sugar", fontsize="x-large")
ax.set_xlabel("salt2", fontsize="x-large")
ax.plot([-20,20],[-20,20], scalex=False, scaley=False)

# %%
fig = plt.figure(figsize=[8,6])
ax2 = fig.add_subplot(111)
mb_salt, mb_sugar = [],[]

for name, HD_salt2 in HD_res_salt2_UBVRI['data'].items():
    if name not in HD_res_sugar_UBVRI['data'].keys():
        print("%s not in sugar"%name)
    else:
        ax2.scatter(HD_res_salt2_UBVRI['data'][name]['residuals'], HD_res_sugar_UBVRI['data'][name]['residuals'], color='g')
    
ax2.set_ylabel("sugar", fontsize="x-large")
ax2.set_xlabel("salt2", fontsize="x-large")
ax2.plot([-20,20],[-20,20], scalex=False, scaley=False)

# %%
fig = plt.figure(figsize=[8,12])
ax2 = fig.add_subplot(511)
ax3 = fig.add_subplot(512)
ax4 = fig.add_subplot(513)
ax5 = fig.add_subplot(514)
ax6 = fig.add_subplot(515)
mbsugar, q1, q2, q3, av, lssfr, proba = [],[],[],[],[], [], []
dmbsugar, dq1, dq2, dq3, dav = [],[],[],[], []

cmap=plt.cm.viridis
for name, HD_salt2 in HD_res_salt2_UBVRI['data'].items():
    if name not in HD_res_sugar_UBVRI['data'].keys():
        print("%s not in sugar"%name)
    else:
        mbsugar.append((HD_res_sugar_UBVRI['data'][name]['mb']))
        q1.append(HD_res_sugar_UBVRI['data'][name]['param_1'])
        q2.append(HD_res_sugar_UBVRI['data'][name]['param_2'])
        q3.append(HD_res_sugar_UBVRI['data'][name]['param_3'])
        av.append(HD_res_sugar_UBVRI['data'][name]['param_4'])
        lssfr.append(HD_res_sugar_UBVRI['data'][name]['lssfr'])
        proba.append(HD_res_sugar_UBVRI['data'][name]['proba'])
        
        dmbsugar.append((HD_res_sugar_UBVRI['data'][name]['mb_err']))
        dq1.append( HD_res_sugar_UBVRI['data'][name]['param_1_err'])
        dq2.append( HD_res_sugar_UBVRI['data'][name]['param_2_err'])
        dq3.append( HD_res_sugar_UBVRI['data'][name]['param_3_err'])
        dav.append( HD_res_sugar_UBVRI['data'][name]['param_4_err'])


q1 = np.array(q1)
q2 = np.array(q2)
q3 = np.array(q3)
av = np.array(av)
lssfr = np.array(lssfr)
proba = np.array(proba)
dq1 = np.array(dq1)
dq2 = np.array(dq2)
dq3 = np.array(dq3)
dav = np.array(dav)
mbsugar = np.array(mbsugar)
dmbsugar = np.array(dmbsugar)

ax2.scatter(lssfr,q1,c=proba)
ax3.scatter(lssfr,q2,c=proba)
ax4.scatter(lssfr,q3,c=proba)
ax5.scatter(lssfr,av,c=proba)
ax6.scatter(lssfr,mbsugar,c=proba)

ax2.set_ylabel("q1", fontsize="x-large")
ax3.set_ylabel("q2", fontsize="x-large")
ax4.set_ylabel("q3", fontsize="x-large")
ax5.set_ylabel("av", fontsize="x-large")
ax6.set_ylabel("mb sugar", fontsize="x-large")

ax6.set_xlabel("log(lsSFR)", fontsize="x-large")
plt.savefig('../../lsfr_analysis/lssfr_sugparam.png')

# %%
plt.scatter(lssfr,av,c=proba)
plt.ylim(-0.5,0.5)
# Out:
# (-0.5, 0.5)

# %%
fig = plt.figure(figsize=[8,12])
ax2 = fig.add_subplot(311)
ax3 = fig.add_subplot(312)
ax4 = fig.add_subplot(313)

mbsalt2, x1, c, lssfr, proba = [],[],[],[],[]
dmbsalt2, dx1, dc = [],[],[]

cmap=plt.cm.viridis
for name, HD_salt2 in HD_res_salt2_UBVRI['data'].items():
    if name not in HD_res_sugar_UBVRI['data'].keys():
        print("%s not in sugar"%name)
    else:
        mbsalt2.append((HD_res_salt2_UBVRI['data'][name]['mb']))
        x1.append(HD_res_salt2_UBVRI['data'][name]['param_1'])
        c.append(HD_res_salt2_UBVRI['data'][name]['param_2'])
        lssfr.append(HD_res_salt2_UBVRI['data'][name]['lssfr'])
        proba.append(HD_res_salt2_UBVRI['data'][name]['proba'])
        
        dmbsalt2.append((HD_res_salt2_UBVRI['data'][name]['mb_err']))
        dx1.append( HD_res_salt2_UBVRI['data'][name]['param_1_err'])
        dc.append( HD_res_salt2_UBVRI['data'][name]['param_2_err'])



x1 = np.array(x1)
c = np.array(c)
lssfr = np.array(lssfr)
proba = np.array(proba)
dx1 = np.array(dx1)
dc = np.array(dc)
mbsalt2 = np.array(mbsalt2)
dmbsalt2 = np.array(dmbsalt2)

ax2.scatter(lssfr,x1,c=proba)
ax3.scatter(lssfr,c,c=proba)
ax4.scatter(lssfr,mbsalt2,c=proba)

ax2.set_ylabel("x1", fontsize="x-large")
ax3.set_ylabel("c", fontsize="x-large")
ax4.set_ylabel("mb salt2", fontsize="x-large")

ax4.set_xlabel("log(lsSFR)", fontsize="x-large")
plt.savefig('../../lsfr_analysis/lssfr_saltparam.png')

# %%
import modefit

xlabel='$\log(lsSFR)$'
ylabel='$q1$ '+ model_name
stepq1 = modefit.stepfit(lssfr, q1, dq1, proba=proba, dx=None, xcut=-10.8, masknan=True, names=None)
stepq1.fit()
FIG = plt.figure(figsize=(9,6))
PLOT = stepq1.show(figure= FIG)
ax = PLOT['ax'][0]
ax.set_ylim(-4.1,4.1)
ax.set_ylabel(ylabel,fontsize=16)
ax.set_xlabel(xlabel,fontsize=16)
PLOT['fig'].subplots_adjust(top=0.97,right=0.99)
#ax.set_title('$\Delta_Y=(%.2f \pm %.2f)$ mag'%((abs(stepq1.modelstep[0]), stepq1.modelstep[1])),ontsize=18)

xlabel='$\log(lsSFR)$'
ylabel='$q2$ '+ model_name
stepq2 = modefit.stepfit(lssfr, q2, dq2, proba=proba, dx=None, xcut=-10.8, masknan=True, names=None)
stepq2.fit()
FIG = plt.figure(figsize=(9,6))
PLOT = stepq2.show(figure= FIG)
ax = PLOT['ax'][0]
ax.set_ylim(-4.1,4.1)
ax.set_ylabel(ylabel,fontsize=16)
ax.set_xlabel(xlabel,fontsize=16)
PLOT['fig'].subplots_adjust(top=0.97,right=0.99)
#ax.set_title('$\Delta_Y=(%.2f \pm %.2f)$ mag'%((abs(stepq1.modelstep[0]), stepq1.modelstep[1])),ontsize=18)

xlabel='$\log(lsSFR)$'
ylabel='$q3$ '+ model_name
stepq3 = modefit.stepfit(lssfr, q3, dq3, proba=proba, dx=None, xcut=-10.8, masknan=True, names=None)
stepq3.fit()
FIG = plt.figure(figsize=(9,6))
PLOT = stepq3.show(figure= FIG)
ax = PLOT['ax'][0]
ax.set_ylim(-4.1,4.1)
ax.set_ylabel(ylabel,fontsize=16)
ax.set_xlabel(xlabel,fontsize=16)
PLOT['fig'].subplots_adjust(top=0.97,right=0.99)
#ax.set_title('$\Delta_Y=(%.2f \pm %.2f)$ mag'%((abs(stepq1.modelstep[0]), stepq1.modelstep[1])),ontsize=18)


xlabel='$\log(lsSFR)$'
ylabel='$mb$ '+ model_name
stepmb = modefit.stepfit(lssfr, mb, dmb, proba=proba, dx=None, xcut=-10.8, masknan=True, names=None)
print stepmb.fit()
FIG = plt.figure(figsize=(9,6))
PLOT = stepmb.show(figure= FIG)
ax = PLOT['ax'][0]
ax.set_ylabel(ylabel,fontsize=16)
ax.set_xlabel(xlabel,fontsize=16)
PLOT['fig'].subplots_adjust(top=0.97,right=0.99)
#ax.set_title('$\Delta_Y=(%.2f \pm %.2f)$ mag'%((abs(stepq1.modelstep[0]), stepq1.modelstep[1])),ontsize=18)
# Out:
# /home/florian/anaconda2/lib/python2.7/site-packages/modefit/bimodal.py:291: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log( self.pdf(x,dx,p) ))
# /home/florian/anaconda2/lib/python2.7/site-packages/scipy/stats/_distn_infrastructure.py:876: RuntimeWarning: invalid value encountered in greater_equal
#   return (self.a <= x) & (x <= self.b)
# /home/florian/anaconda2/lib/python2.7/site-packages/scipy/stats/_distn_infrastructure.py:876: RuntimeWarning: invalid value encountered in less_equal
#   return (self.a <= x) & (x <= self.b)
# /home/florian/anaconda2/lib/python2.7/site-packages/modefit/baseobjects.py:1267: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      mean_a = +nan
#     sigma_a = +0.000000
#      mean_b = +0.000000
#     sigma_b = +0.000000
#
#   self._migrad_output_ = self.minuit.migrad()
# ...

# %%
fig = plt.figure(figsize=[8,6])
ax2 = fig.add_subplot(111)
mb_salt, mb_sugar = [],[]

for name, HD_salt2 in HD_res_salt2_UBVRI['data'].items():
    if name not in HD_res_sugar_UBVRI['data'].keys():
        print("%s not in sugar"%name)
    else:
        ax2.scatter(HD_res_sugar_UBVRI['data'][name]['param_4'], HD_res_salt2_UBVRI['data'][name]['param_2'], color='r')
    
ax2.set_ylabel("sugar", fontsize="x-large")
ax2.set_xlabel("salt2", fontsize="x-large")
ax2.plot([-20,20],[-20,20], scalex=False, scaley=False)

# %% [markdown]
# # LsSFR step in the global fit

# %% [markdown]
# ## Salt2

# %% [markdown]
# ### UBVRI

# %%
model_name='salt2'
rids_salt2 = sa.read_input_data_SNf(res_dict_path='../../sugar_analysis_data/resfitlc_SNf_5new_fU_10new_fI_10_salt2.pkl',model_name=model_name, step_data ='lssfr', select=sample_fixed)
rids_salt2.build_HD_data()
rids_salt2.build_host()
HD_salt2 = sa.get_hubblefit(rids_salt2.params, rids_salt2.cov, rids_salt2.zhl, rids_salt2.zcmb, rids_salt2.zerr, sn_name = rids_salt2.sn_name)
HD_salt2.fit()
# Out:
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:564: InitialParamWarning: errordef is not given. Default to 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:564: InitialParamWarning: Parameter Mb is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:564: InitialParamWarning: Parameter alpha1 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:564: InitialParamWarning: Parameter alpha2 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# ...

# %% [markdown]
# ### BVR

# %%
model_name='salt2'
rids_salt2 = sa.read_input_data_SNf(res_dict_path='../../sugar_analysis_data/resfitlc_SNf_3fB_10fR_10_salt2.pkl',model_name=model_name, step_data ='lssfr', select=sample_fixed)
rids_salt2.build_HD_data()
rids_salt2.build_host()
HD_salt2 = sa.get_hubblefit(rids_salt2.params, rids_salt2.cov, rids_salt2.zhl, rids_salt2.zcmb, rids_salt2.zerr, sn_name = rids_salt2.sn_name)
HD_salt2.fit()
# Out:
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: errordef is not given. Default to 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter Mb is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter alpha1 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter alpha2 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# ...

# %% [markdown]
# ### UBVR

# %%
model_name='salt2'
rids_salt2 = sa.read_input_data_SNf(res_dict_path='../../sugar_analysis_data/resfitlc_SNf_4new_fU_10fR_10_salt2.pkl',model_name=model_name, step_data ='lssfr', select=sample_fixed)
rids_salt2.build_HD_data()
rids_salt2.build_host()
HD_salt2 = sa.get_hubblefit(rids_salt2.params, rids_salt2.cov, rids_salt2.zhl, rids_salt2.zcmb, rids_salt2.zerr, sn_name = rids_salt2.sn_name)
HD_salt2.fit()
# Out:
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: errordef is not given. Default to 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter Mb is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter alpha1 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter alpha2 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# ...

# %% [markdown]
# ## sugar

# %% [markdown]
# ### UBVRI

# %%
model_name='sugar'
rids_sugar = sa.read_input_data_SNf(res_dict_path='../../sugar_analysis_data/resfitlc_SNf_5new_fU_10new_fI_10_sugar.pkl',model_name=model_name, step_data='lssfr', select=sample_fixed)
rids_sugar.build_HD_data()
rids_sugar.build_host()
HD_sugar = sa.get_hubblefit(rids_sugar.params, rids_sugar.cov, rids_sugar.zhl, rids_sugar.zcmb, rids_sugar.zerr, lssfr=np.column_stack((rids_sugar.lssfr,rids_sugar.P_delayed)),sn_name=rids_sugar.sn_name)
HD_sugar.fit()
# Out:
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:564: InitialParamWarning: errordef is not given. Default to 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:564: InitialParamWarning: Parameter Mb is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:564: InitialParamWarning: Parameter alpha1 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:564: InitialParamWarning: Parameter alpha2 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# ...

# %% [markdown]
# ### BVR

# %%
model_name='sugar'
rids_sugar = sa.read_input_data_SNf(res_dict_path='../../sugar_analysis_data/resfitlc_SNf_3fB_10fR_10_sugar.pkl',model_name=model_name, step_data='lssfr', select=sample_fixed)
rids_sugar.build_HD_data()
rids_sugar.build_host()
HD_sugar = sa.get_hubblefit(rids_sugar.params, rids_sugar.cov, rids_sugar.zhl, rids_sugar.zcmb, rids_sugar.zerr, lssfr=np.column_stack((rids_sugar.lssfr,rids_sugar.P_delayed)),sn_name=rids_sugar.sn_name)
HD_sugar.fit()
# Out:
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: errordef is not given. Default to 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter Mb is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter alpha1 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter alpha2 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# ...

# %% [markdown]
# ### UBVR

# %%
model_name='sugar'
rids_sugar = sa.read_input_data_SNf(res_dict_path='../../sugar_analysis_data/resfitlc_SNf_4new_fU_10fR_10_sugar.pkl',model_name=model_name, step_data='lssfr', select=sample_fixed)
rids_sugar.build_HD_data()
rids_sugar.build_host()
HD_sugar = sa.get_hubblefit(rids_sugar.params, rids_sugar.cov, rids_sugar.zhl, rids_sugar.zcmb, rids_sugar.zerr, lssfr=np.column_stack((rids_sugar.lssfr,rids_sugar.P_delayed)),sn_name=rids_sugar.sn_name)
HD_sugar.fit()
# Out:
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: errordef is not given. Default to 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter Mb is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter alpha1 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter alpha2 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# ...

# %% [markdown]
# ## sugar q1

# %%
model_name='sugar'
rids_sugar_q1 = sa.read_input_data_SNf(res_dict_path='../../sugar_analysis_data/resfitlc_SNf_5new_fU_10new_fI_10_sugarq1.pkl', model_name=model_name, step_data='lssfr', select=sample_fixed)
rids_sugar_q1.build_HD_data()
rids_sugar_q1.build_host()
HD_sugar_q1 = sa.get_hubblefit(rids_sugar_q1.params, rids_sugar_q1.cov, rids_sugar_q1.zhl, rids_sugar_q1.zcmb, rids_sugar_q1.zerr, lssfr=np.column_stack((rids_sugar_q1.lssfr,rids_sugar_q1.P_delayed)),sn_name=rids_sugar_q1.sn_name)
HD_sugar_q1.fit()
# Out:
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:564: InitialParamWarning: errordef is not given. Default to 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:564: InitialParamWarning: Parameter Mb is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:564: InitialParamWarning: Parameter alpha1 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:564: InitialParamWarning: Parameter alpha2 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# ...

# %% [markdown]
# # Mass step in the global fit

# %% [markdown]
# # Salt2

# %% [markdown]
# ### UBVRI

# %%
model_name='salt2'
rids_salt2 = sa.read_input_data_SNf(res_dict_path='../../sugar_analysis_data/resfitlc_SNf_5new_fU_10new_fI_10_salt2.pkl',model_name=model_name, step_data='mass', select=sample_fixed)
rids_salt2.build_HD_data()
rids_salt2.build_host()
HD_salt2 = sa.get_hubblefit(rids_salt2.params, rids_salt2.cov, rids_salt2.zhl, rids_salt2.zcmb, rids_salt2.zerr, sn_name=rids_salt2.sn_name)
HD_salt2.fit()
# Out:
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:564: InitialParamWarning: errordef is not given. Default to 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:564: InitialParamWarning: Parameter Mb is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:564: InitialParamWarning: Parameter alpha1 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:564: InitialParamWarning: Parameter alpha2 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# ...

# %% [markdown]
# ### BVR

# %%
model_name='salt2'
rids_salt2 = sa.read_input_data_SNf(res_dict_path='../../sugar_analysis_data/resfitlc_SNf_3fB_10fR_10_salt2.pkl',model_name=model_name, step_data='mass', select=sample_fixed)
rids_salt2.build_HD_data()
rids_salt2.build_host()
HD_salt2 = sa.get_hubblefit(rids_salt2.params, rids_salt2.cov, rids_salt2.zhl, rids_salt2.zcmb, rids_salt2.zerr, sn_name=rids_salt2.sn_name)
HD_salt2.fit()
# Out:
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:564: InitialParamWarning: errordef is not given. Default to 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:564: InitialParamWarning: Parameter Mb is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:564: InitialParamWarning: Parameter alpha1 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:564: InitialParamWarning: Parameter alpha2 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# ...

# %% [markdown]
# ### UBVR

# %%
model_name='salt2'
rids_salt2 = sa.read_input_data_SNf(res_dict_path='../../sugar_analysis_data/resfitlc_SNf_4new_fU_10fR_10_salt2.pkl',model_name=model_name, step_data='mass', select=sample_fixed)
rids_salt2.build_HD_data()
rids_salt2.build_host()
HD_salt2 = sa.get_hubblefit(rids_salt2.params, rids_salt2.cov, rids_salt2.zhl, rids_salt2.zcmb, rids_salt2.zerr, sn_name=rids_salt2.sn_name)
HD_salt2.fit()
# Out:
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: errordef is not given. Default to 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter Mb is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter alpha1 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter alpha2 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# ...

# %% [markdown]
# # Sugar

# %% [markdown]
# ### UBVRI

# %%
model_name='sugar'
rids_sugar = sa.read_input_data_SNf(res_dict_path='../../sugar_analysis_data/resfitlc_SNf_5new_fU_10new_fI_10_sugar.pkl',model_name=model_name, step_data='mass', select=sample_fixed)
rids_sugar.build_HD_data()
rids_sugar.build_host()
HD_sugar = sa.get_hubblefit(rids_sugar.params, rids_sugar.cov, rids_sugar.zhl, rids_sugar.zcmb, rids_sugar.zerr, sn_name=rids_sugar.sn_name)
HD_sugar.fit(Mb_guess = 19.)
# Out:
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:564: InitialParamWarning: errordef is not given. Default to 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:564: InitialParamWarning: Parameter Mb is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:564: InitialParamWarning: Parameter alpha1 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:564: InitialParamWarning: Parameter alpha2 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# ...

# %% [markdown]
# ### BVR

# %%
model_name='sugar'
rids_sugar = sa.read_input_data_SNf(res_dict_path='../../sugar_analysis_data/resfitlc_SNf_3fB_10fR_10_sugar.pkl',model_name=model_name, step_data='mass', select=sample_fixed)
rids_sugar.build_HD_data()
rids_sugar.build_host()
HD_sugar = sa.get_hubblefit(rids_sugar.params, rids_sugar.cov, rids_sugar.zhl, rids_sugar.zcmb, rids_sugar.zerr, sn_name=rids_sugar.sn_name)
HD_sugar.fit(Mb_guess = 19.)
# Out:
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:564: InitialParamWarning: errordef is not given. Default to 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:564: InitialParamWarning: Parameter Mb is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:564: InitialParamWarning: Parameter alpha1 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:564: InitialParamWarning: Parameter alpha2 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# ...

# %% [markdown]
# ### UBVR

# %%
model_name='sugar'
rids_sugar = sa.read_input_data_SNf(res_dict_path='../../sugar_analysis_data/resfitlc_SNf_4new_fU_10fR_10_sugar.pkl',model_name=model_name, step_data='mass', select=sample_fixed)
rids_sugar.build_HD_data()
rids_sugar.build_host()
HD_sugar = sa.get_hubblefit(rids_sugar.params, rids_sugar.cov, rids_sugar.zhl, rids_sugar.zcmb, rids_sugar.zerr, sn_name=rids_sugar.sn_name)
HD_sugar.fit(Mb_guess = 19.)
# Out:
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: errordef is not given. Default to 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter Mb is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter alpha1 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter alpha2 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# ...

# %% [markdown]
# ## Sugar q1

# %% [markdown]
# ### UBVRI

# %%
model_name='sugar'
rids_sugar_q1 = sa.read_input_data_SNf(res_dict_path='../../sugar_analysis_data/resfitlc_SNf_5new_fU_10new_fI_10_sugarq1.pkl', model_name=model_name, step_data='mass', select=sample_fixed)
rids_sugar_q1.build_HD_data()
rids_sugar_q1.build_host()
HD_sugar_q1 = sa.get_hubblefit(rids_sugar_q1.params, rids_sugar_q1.cov, rids_sugar_q1.zhl, rids_sugar_q1.zcmb, rids_sugar_q1.zerr,sn_name=rids_sugar_q1.sn_name)
HD_sugar_q1.fit()
# Out:
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:564: InitialParamWarning: errordef is not given. Default to 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:564: InitialParamWarning: Parameter Mb is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:564: InitialParamWarning: Parameter alpha1 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:564: InitialParamWarning: Parameter alpha2 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# ...

# %% [markdown]
# # Mass step and lssfr step in the global fit

# %% [markdown]
# ## Salt2

# %% [markdown]
# ### UBVRI

# %%
model_name='salt2'
rids_salt2 = sa.read_input_data_SNf(res_dict_path='../../sugar_analysis_data/resfitlc_SNf_5new_fU_10new_fI_10_salt2.pkl',model_name=model_name, step_data='lssfr+mass', select=sample_fixed)
rids_salt2.build_HD_data()
rids_salt2.build_host()
HD_salt2 = sa.get_hubblefit(rids_salt2.params, rids_salt2.cov, rids_salt2.zhl, rids_salt2.zcmb, rids_salt2.zerr, sn_name=rids_salt2.sn_name)
HD_salt2.fit()
# Out:
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: errordef is not given. Default to 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter Mb is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter alpha1 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter alpha2 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# ...

# %% [markdown]
# ### BVR

# %%
model_name='salt2'
rids_salt2 = sa.read_input_data_SNf(res_dict_path='../../sugar_analysis_data/resfitlc_SNf_3fB_10fR_10_salt2.pkl',model_name=model_name, step_data='lssfr+mass', select=sample_fixed)
rids_salt2.build_HD_data()
rids_salt2.build_host()
HD_salt2 = sa.get_hubblefit(rids_salt2.params, rids_salt2.cov, rids_salt2.zhl, rids_salt2.zcmb, rids_salt2.zerr, sn_name=rids_salt2.sn_name)
HD_salt2.fit()
# Out:
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: errordef is not given. Default to 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter Mb is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter alpha1 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter alpha2 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# ...

# %% [markdown]
# ## Sugar

# %% [markdown]
# ### UBVRI

# %%
model_name='sugar'
rids_sugar = sa.read_input_data_SNf(res_dict_path='../../sugar_analysis_data/resfitlc_SNf_5new_fU_10new_fI_10_sugar.pkl',model_name=model_name, step_data='lssfr+mass', select=sample_fixed)
rids_sugar.build_HD_data()
rids_sugar.build_host()
HD_sugar = sa.get_hubblefit(rids_sugar.params, rids_sugar.cov, rids_sugar.zhl, rids_sugar.zcmb, rids_sugar.zerr, sn_name=rids_sugar.sn_name)
HD_sugar.fit(Mb_guess = 19.)
# Out:
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: errordef is not given. Default to 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter Mb is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter alpha1 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter alpha2 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# ...

# %% [markdown]
# ### BVR

# %%
model_name='sugar'
rids_sugar = sa.read_input_data_SNf(res_dict_path='../../sugar_analysis_data/resfitlc_SNf_3fB_10fR_10_sugar.pkl',model_name=model_name, step_data='lssfr+mass', select=sample_fixed)
rids_sugar.build_HD_data()
rids_sugar.build_host()
HD_sugar = sa.get_hubblefit(rids_sugar.params, rids_sugar.cov, rids_sugar.zhl, rids_sugar.zcmb, rids_sugar.zerr, sn_name=rids_sugar.sn_name)
HD_sugar.fit(Mb_guess = 19.)
# Out:
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: errordef is not given. Default to 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter Mb is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter alpha1 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# /home/florian/sugar_analysis/sugar_analysis/Hubble_fit.py:566: InitialParamWarning: Parameter alpha2 is floating but does not have initial step size. Assume 1.
#   self.minuit = minuit.Minuit(self._minuit_chi2_, **minuit_kwargs)
# ...

# %%
len(HD_sugar.sn_name)
# Out:
# 138

# %%
from matplotlib import rc, rcParams
rcParams['font.size'] = 20.
font = {'family': 'normal', 'size': 20}
rc('axes', linewidth=2)
rc('legend', fontsize=25)
rc('xtick.major', size=3, width=3)
rc('ytick.major', size=3, width=3)
rc('xtick.minor', size=5, width=5)
rc('ytick.minor', size=5, width=5)

fig = plt.figure(figsize=[15,13])
ax = fig.add_subplot(111)
DM_salt2 = [0.113,0.089,0.102]
dDM_salt2 = [0.027,0.026,0.026]

DY_salt2 = [0.159,0.131,0.147]
dDY_salt2 = [0.026,0.028,0.025]

DM_sugar = [0.093,0.080,0.091]
dDM_sugar = [0.026,0.028,0.025]

DY_sugar = [0.134,0.118,0.127]
dDY_sugar = [0.028,0.033,0.028]

x = [0,4,8]
x_ticks = ['BVR', 'UBVR', 'UBVRI']
ax.errorbar(x, DM_salt2, yerr=dDM_salt2, c='b', ls='--', label='salt2 DM', marker='o')
ax.errorbar(x, DY_salt2, yerr=dDY_salt2, c='b', label='salt2 DY', marker='o')

ax.errorbar(x, DM_sugar, yerr=dDM_sugar, c='r', ls='--', label='sugar DM', marker='o')
ax.errorbar(x, DY_sugar, yerr=dDY_sugar, c='r', label='sugar DY', marker='o')
plt.xticks(x, x_ticks)
plt.legend()


plt.savefig('../../lsfr_analysis/lssfr_Ubandimpact.png')
